# %% [markdown]
# Que. 1. this is first question?
# - this is the answer.
#
# Que. 2:- this is second question?
# - this is answer for second question.
#
# Que. 3:- this is third question?
# - this is third answer.

# %%
'''abc'''
# Out:
# 'abc'
